# %%
import os
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img_path1= "../test_file/Messi_1.png"
img_path2= "../test_file/Jeff.jpg"

# %%
img_1=cv2.imread(img_path1)
# img_1= cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)
img_2=cv2.imread(img_path2)
# img_2= cv2.cvtColor(img_2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_2)

# %%
result=DeepFace.verify(img_path1,img_path2,model_name="Facenet")

# %%
result
# Out:
# {'verified': False,
#  'distance': 1.0489259490399403,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
DeepFace.stream(db_path="../database",enable_face_analysis=False,model_name="Facenet")
# Out:
# Detector backend is  opencv
# Facenet  is built
# Finding embedding for nabin1.jpg: 100%|██████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.13it/s]
# Embeddings found for given data set in  0.32971787452697754  seconds

# %%
res=DeepFace.detectFace(img_1)

# %%
plt.imshow(res)
